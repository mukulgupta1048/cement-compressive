# %%
# Importing thr libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/gupta/Desktop/Mukul_Projects\Mukul Projects\Project - 1 Data (Concrete Data).csv")
df
# Out:
#       Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse_Aggregate  Fine_Aggregate  Age_in_days  \
# 0               1040.0           676.0           28
# 1               1055.0           676.0           28
# ...

# %%
df.head()
# Out:
#    Cement  Blast_Furnace_Slag  Fly_Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse_Aggregate  Fine_Aggregate  Age_in_days  \
# 0            1040.0           676.0           28
# 1            1055.0           676.0           28
# 2             932.0           594.0          270
# 3             932.0           594.0          365
# 4             978.4           825.5          360
#
#    Concrete_compressive_strength
# 0                          79.99
# 1                          61.89
# 2                          40.27
# 3                          41.05
# 4                          44.30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1030 non-null   float64
#  1   Blast_Furnace_Slag             1030 non-null   float64
#  2   Fly_Ash                        1030 non-null   float64
#  3   Water                          1030 non-null   float64
#  4   Superplasticizer               1030 non-null   float64
#  5   Coarse_Aggregate               1030 non-null   float64
#  6   Fine_Aggregate                 1030 non-null   float64
#  7   Age_in_days                    1030 non-null   int64
#  8   Concrete_compressive_strength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %% [markdown]
# #### We can see all columns have non-null values which means there are no missing values. All the columns are float data types except the age column which is integer.

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Cement                           0
# Blast_Furnace_Slag               0
# Fly_Ash                          0
# Water                            0
# Superplasticizer                 0
# Coarse_Aggregate                 0
# Fine_Aggregate                   0
# Age_in_days                      0
# Concrete_compressive_strength    0
# dtype: int64

# %%
df[df['Age_in_days'] > 365]
# Out:
# Empty DataFrame
# Columns: [Cement, Blast_Furnace_Slag, Fly_Ash, Water, Superplasticizer, Coarse_Aggregate, Fine_Aggregate, Age_in_days, Concrete_compressive_strength]
# Index: []

# %%
df[df['Age_in_days'] < 1]
# Out:
# Empty DataFrame
# Columns: [Cement, Blast_Furnace_Slag, Fly_Ash, Water, Superplasticizer, Coarse_Aggregate, Fine_Aggregate, Age_in_days, Concrete_compressive_strength]
# Index: []

# %%
df.describe()
# Out:
#             Cement  Blast_Furnace_Slag      Fly_Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse_Aggregate  Fine_Aggregate  Age_in_days  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %% [markdown]
# # Data Visualisation
# ## Univariate Analysis

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Cement')
sns.boxplot(df['Cement'] , orient = 'vertical')

plt.subplot(1,2,2)
plt.title(' Blast Furnace Slag ')
sns.boxplot(df['Blast_Furnace_Slag'] , orient = 'vertical')
plt.show()

# %% [markdown]
# ##### For Cement: Box plot shows there are no outliers.
# ##### For Blast slag: Box plot shows outliers are placed just outside the upper limit, do not indicate an anomaly.

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Fly Ash')
sns.boxplot(df['Fly_Ash'] , orient = 'vertical')

plt.subplot(1,2,2)
plt.title(' Water ')
sns.boxplot(df['Water'] , orient = 'vertical')
plt.show()

# %% [markdown]
# ##### For Fly Ash: Box plot shows there are no outliers
# ##### For Water: Box plot shows very few outliers on both sides, but do not indicate an anomaly.

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Coarse_ Aggregate')
sns.boxplot(df['Coarse_Aggregate'] , orient = 'vertical')

plt.subplot(1,2,2)
plt.title(' Fine Aggregate ')
sns.boxplot(df['Fine_Aggregate'] , orient = 'vertical')
plt.show()

# %% [markdown]
# ##### For Coarse Aggregate : Box plot shows there are no outliers.
# ##### For Fine Aggregate :Box plot shows few outliers on higher side.

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Superplasticizer')
sns.boxplot(df['Superplasticizer'] , orient = 'vertical')

plt.subplot(1,2,2)
plt.title(' Age ')
sns.boxplot(df['Age_in_days'] , orient = 'vertical')
plt.show()

# %% [markdown]
# ##### For Superplasticizer : Box plot shows few outliers on higher side but does not effect the results.
# ##### For Age : Box plot shows outliers on higher side. But it is not an anomaly, it is due to the fact that concrete strength data is collected at age of upto 28 days, then at ages of 6 months, 9 months and 1 year.

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.regplot(x='Cement',y='Concrete_compressive_strength', data=df)

# %% [markdown]
# #### It seems is a positive relationship.

# %%
sns.jointplot(x='Blast_Furnace_Slag',y='Concrete_compressive_strength', kind='kde',data=df)

# %% [markdown]
# Data here seems to have more variance. It seems that this feature is more important in certain cases on the industry. We see that with values of 200, the Concrete_compressive_strength decreases a little, which is expected. For smaller values than 100 the Concrete_compressive_strength is more disperse.

# %%
sns.jointplot(x='Fly_Ash',y='Concrete_compressive_strength',kind='kde', data=df)

sns.jointplot(x='Water',y='Concrete_compressive_strength',kind='reg' ,  data=df)
plt.show()

# %% [markdown]
# #### For fly_ash-------> Compressive strength decreases when fly_ash increases.
# #### For Water---------> It depends on the how old the concrete is.

# %%
sns.jointplot(x='Superplasticizer',y='Concrete_compressive_strength',kind='kde',data=df)
plt.show()

# %% [markdown]
# Superplasticizer (high range water reducing admixture) Admixture which permits a high reduction in the water content of a given mix without affecting the consistence, or which increases the slump/flow considerably without affecting the water content or produces both effects simultaneously.
#
# #### The use of superpasticizer aims to reduce the use of Water in concrete which would decrease the strength even more.

# %%
def scatter(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(df[x],df['Concrete_compressive_strength'])
    plt.title(x+' vs Concrete_compressive_strength')
    plt.ylabel('Concrete_compressive_strength')
    plt.xlabel(x)

plt.figure(figsize=(10,20))

scatter('Coarse_Aggregate', 1)
scatter('Fine_Aggregate', 2)


plt.tight_layout()

# %% [markdown]
# The effect of Coarser and Fine Aggregators seems to have a small negative impact when increasing their percentage , but we will take these features as important.

# %%
sns.jointplot(x='Age_in_days',y='Concrete_compressive_strength',  kind='reg', data=df)

# %% [markdown]
# It looks like that, with more days, our concrete becomes more stronger.

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize = (10 ,8))
sns.heatmap(df.corr(),annot = True)
plt.show()

# %% [raw]
# We can observe :
# a) a high corelation between concrete compressive Strength and Cement
# b) Age and Super Plasticizer are the other two factors influencing Compressive strength.
# c) positive correlations between Super Plasticizer and Fly Ash, Fine Aggregate.
# d) A strong negative correlation between Super Plasticizer and Water
#
# These correlations are useful to understand the data in detail, as they give an idea about how a variable is affecting the others.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Model-1
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Train-Test split and Feature Scaling

# %%
X = df.iloc[:,:-1] # Features 
y = df.iloc[:,-1] # Target 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2) 
sc = StandardScaler() 
X_train = sc.fit_transform(X_train) 
X_test = sc.transform(X_test)

# %%
# Linear Regression Equation:

# Y = Bo + B1x

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred_lr = lr.predict(X_test)

plt.scatter(x = y_test, y = y_pred_lr)

# %%
print('R2 score: ',r2_score(y_test,y_pred_lr))
# Out:
# R2 score:  0.5701142652757779

# %%
print('Root Mean sq. error: ',np.sqrt(mean_squared_error(y_test, y_pred_lr)))
# Out:
# Root Mean sq. error:  10.284178249008416

# %% [markdown]
# # Model-2
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(X_train,y_train)
rfr.score(X_train,y_train)
y_pred_rfrtr=rfr.predict(X_train)
y_pred_rfrte=rfr.predict(X_test)
print('Train R2 score: ',r2_score(y_train,y_pred_rfrtr))
print('Test R2 score: ',r2_score(y_test,y_pred_rfrte))
print('Train Root Mean sq. error: ',np.sqrt(mean_squared_error(y_train,y_pred_rfrtr)))
print('Test Root Mean sq. error: ',np.sqrt(mean_squared_error(y_test,y_pred_rfrte)))
# Out:
# Train R2 score:  0.9849180597996712
# Test R2 score:  0.897000767581767
# Train Root Mean sq. error:  2.080151689875289
# Test Root Mean sq. error:  5.033963619827474

# %% [markdown]
# The random forest is overfitting but has improved the model performance

# %%
plt.scatter(x = y_test, y = y_pred_rfrte)
plt.show()

# %%
req_col_names = ["Cement", "Blast_Furnace_Slag", "Fly_Ash", "Water", "Superplasticizer",
                 "Coarse_Aggregate", "Fine_Aggregate", "Age_in_days", "Concrete_compressive_strength"]

feature_rfr = rfr.feature_importances_

labels = req_col_names[:-1]

x = np.arange(len(labels)) 
width = 0.3

fig, ax = plt.subplots(figsize=(10,6))

rects2 = ax.bar(x+(width/2), feature_rfr, width, label='Random Forest')

ax.set_ylabel('Importance')
ax.set_xlabel('Features')
ax.set_title('Feature Importance')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
ax.legend(loc="upper left", bbox_to_anchor=(1,1))

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.2f}'.format(height), xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points", ha='center', va='bottom')

autolabel(rects2)

fig.tight_layout()
plt.show()

# %% [markdown]
# ##### Cement and Age are treated as the most important features by tree based model. Flyash, Coarse and Fine aggregates are least important factors when predicting the strength of Concrete.
#
# ### Evaluate both models on the test set
# #### LINEAR REGRESSION
#
# - R2 SCORE-----0.57
# - RMSE ----------10.28
#
# #### RANDOM FOREST
#
#
# - R2 SCORE-----0.90
# - RMSE -----------5.10

# %% [markdown]
# ##### <font color = darkgreen>  So, according to the metrics performance we can say that  RANDOM FOREST has better R2 score than LINEAR REGRESSION.</font>
